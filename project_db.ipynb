# %%
import pymysql
import pandas as pd
import openpyxl
import numpy
import datetime

# %%
db = pymysql.connect(host='15.164.171.72', port=3306, user='joy', passwd='Ghfkddl~1283', db='project_one', charset='utf8')

# %%
cur = db.cursor()

# %%
CREATE_SQL ='''
CREATE TABLE IF NOT EXISTS grain(
    id integer auto_increment,
    날짜 date,
    곡류 VARCHAR(10) ,
    open FLOAT,
    close FLOAT,
    정착가 FLOAT,
    양 INT,
    primary key(id)
    );
    '''

# %%
cur.execute(CREATE_SQL)
# Out:
# 0

# %%
db.commit()

# %%
grain = pd.read_excel("data/곡물 종합 데이터.xlsx")
grain
# Out:
#           Date Type    Open   Close  정착가/달러  Volume/톤
# 0   2021-10-01    밀  266.39  278.33  277.50    136040
# 1   2021-10-01   대두  461.13  457.45  458.00    195830
# 2   2021-10-01  옥수수  211.31  213.18  213.18    218676
# 3   2021-10-04    밀  276.40  277.87  277.96     90693
# 4   2021-10-04   대두  456.62  452.77  454.05    194154
# ..         ...  ...     ...     ...     ...       ...
# 403 2022-04-12   대두  609.48  613.61  613.70    204202
# 404 2022-04-12  옥수수  301.37  305.11  305.60    339229
# 405 2022-04-13    밀  405.09  409.69  409.13    132978
# 406 2022-04-13   대두  614.44  614.07  615.81    223967
# 407 2022-04-13  옥수수  305.11  308.35  308.45    395446
#
# [408 rows x 6 columns]

# %%
grain["Date"] = pd.to_datetime(grain["Date"])

# %%
grain.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 408 entries, 0 to 407
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      408 non-null    datetime64[ns]
#  1   Type      408 non-null    object
#  2   Open      408 non-null    float64
#  3   Close     408 non-null    float64
#  4   정착가/달러    408 non-null    float64
#  5   Volume/톤  408 non-null    int64
# dtypes: datetime64[ns](1), float64(3), int64(1), object(1)
# memory usage: 19.2+ KB

# %%
sql = "INSERT INTO grain(날짜,곡류,open,close,정착가,양) VALUES(%s,%s,%s,%s,%s,%s)"
for idx in range(len(grain)):
    cur.execute(sql,tuple(grain.values[idx]))

# %%
db.commit()

# %%
domestic_oil = pd.read_excel("data/국내기름가격.xlsx")
domestic_oil
# Out:
#               날짜    고급휘발유    보통휘발유   자동차용경유     실내등유
# 0    2021년10월01일  1885.66  1648.21  1443.14   946.10
# 1    2021년10월02일  1886.37  1649.52  1444.57   947.17
# 2    2021년10월03일  1886.54  1650.24  1445.08   947.72
# 3    2021년10월04일  1887.18  1651.18  1446.28   947.96
# 4    2021년10월05일  1888.63  1652.92  1448.18   948.81
# ..           ...      ...      ...      ...      ...
# 190  2022년04월09일  2194.44  1982.90  1906.17  1426.61
# 191  2022년04월10일  2193.56  1982.06  1905.50  1426.73
# 192  2022년04월11일  2193.61  1980.41  1904.54  1426.81
# 193  2022년04월12일  2193.28  1976.94  1902.53  1426.82
# 194  2022년04월13일  2192.16  1974.21  1900.84  1426.74
#
# [195 rows x 5 columns]

# %%
domestic_oil["날짜"]=domestic_oil["날짜"].str.replace("년","-")
domestic_oil["날짜"]=domestic_oil["날짜"].str.replace("월","-")
domestic_oil["날짜"]=domestic_oil["날짜"].str.replace("일","")

# %%
domestic_oil
# Out:
#              날짜    고급휘발유    보통휘발유   자동차용경유     실내등유
# 0    2021-10-01  1885.66  1648.21  1443.14   946.10
# 1    2021-10-02  1886.37  1649.52  1444.57   947.17
# 2    2021-10-03  1886.54  1650.24  1445.08   947.72
# 3    2021-10-04  1887.18  1651.18  1446.28   947.96
# 4    2021-10-05  1888.63  1652.92  1448.18   948.81
# ..          ...      ...      ...      ...      ...
# 190  2022-04-09  2194.44  1982.90  1906.17  1426.61
# 191  2022-04-10  2193.56  1982.06  1905.50  1426.73
# 192  2022-04-11  2193.61  1980.41  1904.54  1426.81
# 193  2022-04-12  2193.28  1976.94  1902.53  1426.82
# 194  2022-04-13  2192.16  1974.21  1900.84  1426.74
#
# [195 rows x 5 columns]

# %%
domestic_oil["날짜"] = pd.to_datetime(domestic_oil["날짜"])

# %%
domestic_oil.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   날짜      195 non-null    datetime64[ns]
#  1   고급휘발유   195 non-null    float64
#  2   보통휘발유   195 non-null    float64
#  3   자동차용경유  195 non-null    float64
#  4   실내등유    195 non-null    float64
# dtypes: datetime64[ns](1), float64(4)
# memory usage: 7.7 KB

# %%
CREATE_SQL2 ='''
CREATE TABLE IF NOT EXISTS domestic_oil(
    id integer auto_increment,
    날짜 date,
    고급휘발유 FLOAT,
    보통휘발유 FLOAT,
    자동차용경유 FLOAT,
    실내등유 FLOAT,
    primary key(id)
    );
    '''

# %%
cur.execute(CREATE_SQL2)
# Out:
# 0

# %%
db.commit()

# %%
sql2 = "INSERT INTO domestic_oil(날짜,고급휘발유,보통휘발유,자동차용경유,실내등유) VALUES(%s,%s,%s,%s,%s)"

# %%
for idx in range(len(domestic_oil)):
    cur.execute(sql2,tuple(domestic_oil.values[idx]))

# %%
# 제대로 입력 되었는지 확인 작업
for idx in range(len(domestic_oil)):
    print(tuple(domestic_oil.values[idx]))
# Out:
# (Timestamp('2021-10-01 00:00:00'), 1885.66, 1648.21, 1443.14, 946.1)
# (Timestamp('2021-10-02 00:00:00'), 1886.37, 1649.52, 1444.57, 947.17)
# (Timestamp('2021-10-03 00:00:00'), 1886.54, 1650.24, 1445.08, 947.72)
# (Timestamp('2021-10-04 00:00:00'), 1887.18, 1651.18, 1446.28, 947.96)
# (Timestamp('2021-10-05 00:00:00'), 1888.63, 1652.92, 1448.18, 948.81)
# (Timestamp('2021-10-06 00:00:00'), 1891.84, 1656.81, 1452.28, 949.68)
# (Timestamp('2021-10-07 00:00:00'), 1895.49, 1661.16, 1456.8, 951.19)
# (Timestamp('2021-10-08 00:00:00'), 1904.09, 1667.13, 1462.87, 953.79)
# (Timestamp('2021-10-09 00:00:00'), 1907.68, 1673.01, 1468.94, 957.76)
# (Timestamp('2021-10-10 00:00:00'), 1909.44, 1676.42, 1472.26, 959.67)
# (Timestamp('2022-02-14 00:00:00'), 1934.72, 1714.12, 1535.33, 1171.58)
# (Timestamp('2022-02-15 00:00:00'), 1938.18, 1718.64, 1540.24, 1175.83)
# (Timestamp('2022-02-16 00:00:00'), 1942.47, 1722.69, 1545.08, 1180.25)
# (Timestamp('2022-02-17 00:00:00'), 1944.94, 1726.09, 1549.04, 1183.44)
# (Timestamp('2022-02-18 00:00:00'), 1948.02, 1729.39, 1552.79, 1186.77)
# (Timestamp('2022-02-19 00:00:00'), 1950.32, 1732.31, 1555.98, 1189.85)
# (Timestamp('2022-02-20 00:00:00'), 1951.75, 1733.84, 1557.47, 1191.1)
# (Timestamp('2022-02-21 00:00:00'), 1953.51, 1736.48, 1560.65, 1193.3)
# (Timestamp('2022-02-22 00:00:00'), 1955.69, 1739.36, 1563.99, 1195.74)
# (Timestamp('2022-02-23 00:00:00'), 1958.38, 1743.05, 1568.31, 1199.43)
# (Timestamp('2022-02-24 00:00:00'), 1960.22, 1746.2, 1572.03, 1202.08)
# (Timestamp('2022-02-25 00:00:00'), 1963.42, 1750.84, 1577.05, 1205.59)
# (Timestamp('2022-02-26 00:00:00'), 1967.62, 1754.75, 1581.41, 1208.89)
# (Timestamp('2022-02-27 00:00:00'), 1968.72, 1756.31, 1582.87, 1210.07)
# (Timestamp('2022-02-28 00:00:00'), 1970.54, 1758.87, 1585.96, 1211.75)
# (Timestamp('2022-03-01 00:00:00'), 1978.01, 1763.32, 1590.62, 1214.21)
# (Timestamp('2022-03-02 00:00:00'), 1980.57, 1767.09, 1594.81, 1216.86)
# (Timestamp('2022-03-03 00:00:00'), 1987.1, 1774.18, 1602.22, 1220.89)
# (Timestamp('2022-03-04 00:00:00'), 2001.17, 1786.04, 1615.37, 1228.35)
# (Timestamp('2022-03-05 00:00:00'), 2013.77, 1803.2, 1634.99, 1240.06)
# (Timestamp('2022-03-06 00:00:00'), 2021.93, 1812.9, 1646.01, 1246.39)
# (Timestamp('2022-03-07 00:00:00'), 2033.12, 1828.34, 1665.13, 1254.34)
# (Timestamp('2022-03-08 00:00:00'), 2070.15, 1860.61, 1706.45, 1274.04)
# (Timestamp('2022-03-09 00:00:00'), 2101.67, 1892.4, 1750.15, 1293.64)
# (Timestamp('2022-03-10 00:00:00'), 2121.7, 1913.73, 1781.84, 1307.9)
# (Timestamp('2022-03-11 00:00:00'), 2152.86, 1938.97, 1818.45, 1326.41)
# (Timestamp('2022-03-12 00:00:00'), 2178.73, 1965.03, 1857.08, 1346.39)
# (Timestamp('2022-03-13 00:00:00'), 2186.06, 1975.36, 1872.63, 1354.27)
# (Timestamp('2022-03-14 00:00:00'), 2199.38, 1988.04, 1892.42, 1365.14)
# (Timestamp('2022-03-15 00:00:00'), 2215.11, 2000.95, 1912.14, 1379.04)
# (Timestamp('2022-03-16 00:00:00'), 2220.36, 2004.23, 1917.89, 1387.36)
# (Timestamp('2022-03-17 00:00:00'), 2220.83, 2003.42, 1917.35, 1392.28)
# (Timestamp('2022-03-18 00:00:00'), 2219.27, 2002.56, 1917.35, 1397.91)
# (Timestamp('2022-03-19 00:00:00'), 2217.84, 2002.13, 1917.14, 1402.4)
# (Timestamp('2022-03-20 00:00:00'), 2217.71, 2002.18, 1917.39, 1403.61)
# (Timestamp('2022-03-21 00:00:00'), 2218.15, 2002.12, 1917.82, 1405.24)
# (Timestamp('2022-03-22 00:00:00'), 2217.07, 2001.84, 1917.89, 1406.68)
# (Timestamp('2022-03-23 00:00:00'), 2217.07, 2001.72, 1918.25, 1408.77)
# (Timestamp('2022-03-24 00:00:00'), 2216.29, 2001.81, 1918.92, 1410.77)
# (Timestamp('2022-03-25 00:00:00'), 2214.41, 2001.92, 1919.65, 1412.95)
# (Timestamp('2022-03-26 00:00:00'), 2212.9, 2000.65, 1919.15, 1415.09)
# (Timestamp('2022-03-27 00:00:00'), 2213.04, 2000.85, 1919.61, 1415.57)
# (Timestamp('2022-03-28 00:00:00'), 2212.79, 2001.15, 1920.44, 1416.78)
# (Timestamp('2022-03-29 00:00:00'), 2214.23, 2000.45, 1920.32, 1418.78)
# (Timestamp('2022-03-30 00:00:00'), 2213.16, 1999.44, 1919.72, 1420.21)
# (Timestamp('2022-03-31 00:00:00'), 2212.71, 1998.39, 1918.84, 1421.21)
# (Timestamp('2022-04-01 00:00:00'), 2211.45, 1996.11, 1916.89, 1422.72)
# (Timestamp('2022-04-02 00:00:00'), 2204.68, 1994.54, 1915.18, 1423.37)
# (Timestamp('2022-04-03 00:00:00'), 2202.84, 1993.97, 1914.62, 1423.33)
# (Timestamp('2022-04-04 00:00:00'), 2202.56, 1992.3, 1913.19, 1423.94)
# (Timestamp('2022-04-05 00:00:00'), 2198.4, 1990.23, 1911.37, 1424.51)
# (Timestamp('2022-04-06 00:00:00'), 2198.49, 1988.81, 1910.43, 1425.07)
# (Timestamp('2022-04-07 00:00:00'), 2196.66, 1987.04, 1909.18, 1425.64)
# (Timestamp('2022-04-08 00:00:00'), 2195.6, 1984.87, 1907.86, 1426.28)
# (Timestamp('2022-04-09 00:00:00'), 2194.44, 1982.9, 1906.17, 1426.61)
# (Timestamp('2022-04-10 00:00:00'), 2193.56, 1982.06, 1905.5, 1426.73)
# (Timestamp('2022-04-11 00:00:00'), 2193.61, 1980.41, 1904.54, 1426.81)
# (Timestamp('2022-04-12 00:00:00'), 2193.28, 1976.94, 1902.53, 1426.82)
# (Timestamp('2022-04-13 00:00:00'), 2192.16, 1974.21, 1900.84, 1426.74)

# %%
db.commit()

# %%
oversea_oil = pd.read_excel("data/국제기름가격.xlsx")
oversea_oil
# Out:
#            일  Unnamed: 1  휘발유(95RON)  휘발유(92RON)      등유  경유(0.05%)  \
# 0    10월 01일         NaN       88.18       85.82   85.78      85.60
# 1    10월 04일         NaN       89.69       87.33   87.82      87.37
# 2    10월 05일         NaN       92.48       90.12   90.82      90.30
# 3    10월 06일         NaN       94.39       92.03   92.79      92.68
# 4    10월 07일         NaN       90.52       88.49   87.74      87.74
# ..       ...         ...         ...         ...     ...        ...
# 130  04월 07일         NaN      121.56      118.04  126.20     130.82
# 131  04월 08일         NaN      121.64      118.54  124.73     129.64
# 132  04월 11일         NaN      120.72      117.49  124.31     129.12
# 133  04월 12일         NaN      118.94      116.08  126.77     131.96
# 134  04월 13일         NaN      123.52      120.86  131.51     138.61
#
#      경유(0.001%)
# 0         88.56
# 1         90.33
# 2         93.22
# 3         95.38
# 4         90.41
# ..          ...
# 130      139.17
# 131      137.99
# 132      137.64
# 133      141.48
# 134      148.41
#
# [135 rows x 7 columns]

# %%
oversea_oil.drop(["Unnamed: 1"], axis = 1, inplace = True)

# %%
for i in range(len(oversea_oil)):
    if i <= 63 :
        oversea_oil.iloc[i,0] = "2021년" + oversea_oil.iloc[i,0]
    else :
        oversea_oil.iloc[i,0] = "2022년" + oversea_oil.iloc[i,0]

# %%
oversea_oil.iloc[0,0]
# Out:
# '2021년10월\xa001일'

# %%
oversea_oil["일"]=oversea_oil["일"].str.replace("년","-")
oversea_oil["일"]=oversea_oil["일"].str.replace("월","-")
# \xa0 제거
oversea_oil["일"]=oversea_oil["일"].str.replace("\xa0","")

oversea_oil["일"]=oversea_oil["일"].str.replace("일","")

# %%
oversea_oil
# Out:
#               일  휘발유(95RON)  휘발유(92RON)      등유  경유(0.05%)  경유(0.001%)
# 0    2021-10-01       88.18       85.82   85.78      85.60       88.56
# 1    2021-10-04       89.69       87.33   87.82      87.37       90.33
# 2    2021-10-05       92.48       90.12   90.82      90.30       93.22
# 3    2021-10-06       94.39       92.03   92.79      92.68       95.38
# 4    2021-10-07       90.52       88.49   87.74      87.74       90.41
# ..          ...         ...         ...     ...        ...         ...
# 130  2022-04-07      121.56      118.04  126.20     130.82      139.17
# 131  2022-04-08      121.64      118.54  124.73     129.64      137.99
# 132  2022-04-11      120.72      117.49  124.31     129.12      137.64
# 133  2022-04-12      118.94      116.08  126.77     131.96      141.48
# 134  2022-04-13      123.52      120.86  131.51     138.61      148.41
#
# [135 rows x 6 columns]

# %%
oversea_oil["일"] = pd.to_datetime(oversea_oil["일"])

# %%
oversea_oil.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 135 entries, 0 to 134
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   일           135 non-null    datetime64[ns]
#  1   휘발유(95RON)  135 non-null    float64
#  2   휘발유(92RON)  135 non-null    float64
#  3   등유          135 non-null    float64
#  4   경유(0.05%)   135 non-null    float64
#  5   경유(0.001%)  135 non-null    float64
# dtypes: datetime64[ns](1), float64(5)
# memory usage: 6.5 KB

# %%
CREATE_SQL3 ='''
CREATE TABLE IF NOT EXISTS oversea_oil(
    id integer auto_increment,
    날짜 date,
    휘발유_95ron FLOAT,
    휘발유_92ron FLOAT,
    등유 FLOAT,
    경유005  FLOAT,
    경유0001 FLOAT,
    primary key(id)
    );
    '''

# %%
cur.execute(CREATE_SQL3)
# Out:
# 0

# %%
db.commit()

# %%
sql3 = "INSERT INTO oversea_oil(날짜,휘발유_95ron,휘발유_92ron,등유,경유005,경유0001) VALUES(%s,%s,%s,%s,%s,%s)"

# %%
for idx in range(len(oversea_oil)):
    cur.execute(sql3,tuple(oversea_oil.values[idx]))

# %%
db.commit()

# %% [markdown]
# ## 월평균 데이터

# %% [markdown]
# #### 월평균 국내기름 데이터

# %%
monthly_domestic_oil = pd.read_excel("data/국내기름 월평균 가격.xlsx")
monthly_domestic_oil
# Out:
#           구분    고급휘발유    보통휘발유   자동차용경유
# 0   2021년10월  1938.16  1712.32  1509.29
# 1   2021년11월  1946.19  1737.39  1549.72
# 2   2021년12월  1871.86  1646.37  1468.90
# 3   2022년01월  1870.54  1635.22  1453.53
# 4   2022년02월  1935.63  1714.61  1536.64
# 5   2022년03월  2151.54  1938.46  1826.93
# 6  단위 : 원/리터      NaN      NaN      NaN

# %%
monthly_domestic_oil = monthly_domestic_oil.drop([monthly_domestic_oil.index[6]])

# %%
monthly_domestic_oil["구분"]=monthly_domestic_oil["구분"].str.replace("년","-")
monthly_domestic_oil["구분"]=monthly_domestic_oil["구분"].str.replace("월","")

# %%
monthly_domestic_oil
# Out:
#         구분    고급휘발유    보통휘발유   자동차용경유
# 0  2021-10  1938.16  1712.32  1509.29
# 1  2021-11  1946.19  1737.39  1549.72
# 2  2021-12  1871.86  1646.37  1468.90
# 3  2022-01  1870.54  1635.22  1453.53
# 4  2022-02  1935.63  1714.61  1536.64
# 5  2022-03  2151.54  1938.46  1826.93

# %%
CREATE_SQL5 = '''
CREATE TABLE IF NOT EXISTS monthly_domestic_oil(
    id integer auto_increment,
    날짜 TEXT,
    고급휘발유 FLOAT,
    보통휘발유 FLOAT,
    자동차용경유 FLOAT,
    primary key(id)
    );
    '''

# %%
cur.execute(CREATE_SQL5)
# Out:
# 0

# %%
db.commit()

# %%
sql5 = "INSERT INTO monthly_domestic_oil(날짜,고급휘발유,보통휘발유,자동차용경유) VALUES(%s,%s,%s,%s)"

# %%
for idx in range(len(monthly_domestic_oil)):
    cur.execute(sql5,tuple(monthly_domestic_oil.values[idx]))

# %%
db.commit()

# %% [markdown]
# ### 월평균 국제기름 가격

# %%
monthly_oversea_oil = pd.read_excel("data/국제기름 월평균 가격.xlsx")
monthly_oversea_oil
# Out:
#                월  휘발유(95RON)  휘발유(92RON)  경유(0.001%)
# 0            10월       98.68       95.79       95.53
# 1            11월       94.95       92.22       91.56
# 2            12월       87.89       85.69       85.87
# 3        22년 01월       98.08       96.18       99.16
# 4            02월      110.81      108.31      110.77
# 5            03월      131.15      127.46      141.75
# 6  (단 위 : $/Bbl)         NaN         NaN         NaN

# %%
monthly_oversea_oil = monthly_oversea_oil.drop([monthly_oversea_oil.index[6]])

# %%
monthly_oversea_oil["월"] = ["2021-10","2021-11","2021-12","2022-01","2022-02","2022-03"]

# %%
monthly_oversea_oil
# Out:
#          월  휘발유(95RON)  휘발유(92RON)  경유(0.001%)
# 0  2021-10       98.68       95.79       95.53
# 1  2021-11       94.95       92.22       91.56
# 2  2021-12       87.89       85.69       85.87
# 3  2022-01       98.08       96.18       99.16
# 4  2022-02      110.81      108.31      110.77
# 5  2022-03      131.15      127.46      141.75

# %%
CREATE_SQL6 = '''
CREATE TABLE IF NOT EXISTS monthly_oversea_oil(
    id integer auto_increment,
    날짜 TEXT,
    휘발유_95RON FLOAT,
    휘발유_92RON FLOAT,
    경유0001 FLOAT,
    primary key(id)
    );
    '''

# %%
cur.execute(CREATE_SQL6)
# Out:
# 0

# %%
db.commit()

# %%
sql6 = "INSERT INTO monthly_oversea_oil(날짜,휘발유_95RON,휘발유_92RON,경유0001) VALUES(%s,%s,%s,%s)"

# %%
for idx in range(len(monthly_oversea_oil)):
    cur.execute(sql6,tuple(monthly_oversea_oil.values[idx]))

# %%
db.commit()

# %% [markdown]
# ### 월평균 국내기름 데이터

# %%
monthly_grain = pd.read_excel("data/곡물 월평균 가격.xlsx")
monthly_grain
# Out:
#      Unnamed: 0          대두           밀         옥수수
# 0           10월  452.014762  273.936667  211.259524
# 1           11월  456.236667  296.323810  224.751905
# 2           12월  474.482727  290.420455  233.133182
# 3            1월  514.864000  283.819500  239.915500
# 4            2월  583.684211  296.119474  255.380000
# 5            3월  614.828696  407.026522  294.016250
# 6  단위 : USD/ton         NaN         NaN         NaN

# %%
monthly_grain = monthly_grain.drop([monthly_grain.index[6]])

# %%
monthly_grain["Unnamed: 0"] = ["2021-10","2021-11","2021-12","2022-01","2022-02","2022-03"]

# %%
monthly_grain
# Out:
#   Unnamed: 0          대두           밀         옥수수
# 0    2021-10  452.014762  273.936667  211.259524
# 1    2021-11  456.236667  296.323810  224.751905
# 2    2021-12  474.482727  290.420455  233.133182
# 3    2022-01  514.864000  283.819500  239.915500
# 4    2022-02  583.684211  296.119474  255.380000
# 5    2022-03  614.828696  407.026522  294.016250

# %%
CREATE_SQL7 = '''
CREATE TABLE IF NOT EXISTS monthly_grain(
    id integer auto_increment,
    날짜 TEXT,
    대두 FLOAT,
    밀 FLOAT,
    옥수수 FLOAT,
    primary key(id)
    );
    '''

# %%
cur.execute(CREATE_SQL7)
# Out:
# 0

# %%
db.commit()

# %%
sql7 = "INSERT INTO monthly_grain(날짜,대두,밀,옥수수) VALUES(%s,%s,%s,%s)"

# %%
for idx in range(len(monthly_grain)):
    cur.execute(sql7,tuple(monthly_grain.values[idx]))

# %%
db.commit()

# %% [markdown]
# ### 광물 데이터

# %%
mineral = pd.read_excel("data/광물종합데이터.xlsx")
mineral
# Out:
#             기준일    알루미늄     니켈        동      아연     주석
# 0    2021-10-01  2865.0  18125   9113.0  2999.0  35600
# 1    2021-10-04  2889.0  18140   9267.5  3013.0  35800
# 2    2021-10-05  2894.5  17800   9091.5  3011.5  36400
# 3    2021-10-06  2880.0  18095   9096.0  3015.0  36750
# 4    2021-10-07  2916.0  18240   9177.0  3025.0  36205
# ..          ...     ...    ...      ...     ...    ...
# 131  2022-04-07  3346.0  33500  10292.0  4250.0  44300
# 132  2022-04-08  3395.0  34100  10390.0  4280.0  44295
# 133  2022-04-11  3234.5  32925  10235.5  4372.0  43325
# 134  2022-04-12  3214.5  32450  10201.0  4345.0  43650
# 135  2022-04-13  3207.0  33000  10290.5  4515.0  43450
#
# [136 rows x 6 columns]

# %%
mineral["기준일"] = pd.to_datetime(mineral["기준일"])

# %%
CREATE_SQL9 = '''
CREATE TABLE IF NOT EXISTS mineral(
    id integer auto_increment,
    날짜 DATE,
    알루미늄 FLOAT,
    니켈 FLOAT,
    동 FLOAT,
    아연 FLOAT,
    주석 FLOAT,
    primary key(id)
    );
    '''

# %%
cur.execute(CREATE_SQL9)
# Out:
# 0

# %%
db.commit()

# %%
sql9 = "INSERT INTO mineral(날짜,알루미늄,니켈,동,아연,주석) VALUES(%s,%s,%s,%s,%s,%s)"

# %%
for idx in range(len(mineral)):
    cur.execute(sql9,tuple(mineral.values[idx]))

# %%
db.commit()

# %% [markdown]
# ### 월평균 광물데이터

# %%
monthly_mineral = pd.read_excel("data/광물종합월평균데이터.xlsx")
monthly_mineral
# Out:
#      월     알루미늄        니켈         동       아연        주석
# 0  10월  2955.17  19420.24   9778.50  3370.14  37962.38
# 1  11월  2641.41  19964.32   9765.48  3317.30  39332.73
# 2  12월  2695.36  20070.24   9550.31  3407.88  39573.81
# 3   1월  3003.08  22326.00   9775.93  3609.95  41807.00
# 4   2월  3260.83  24178.00   9941.35  3644.23  44117.75
# 5   3월  3537.85  31860.65  10237.59  3974.30  44248.91

# %%
monthly_mineral['월'] = ["2021-10","2021-11","2021-12","2022-01","2022-02","2022-03"]

# %%
monthly_mineral
# Out:
#          월     알루미늄        니켈         동       아연        주석
# 0  2021-10  2955.17  19420.24   9778.50  3370.14  37962.38
# 1  2021-11  2641.41  19964.32   9765.48  3317.30  39332.73
# 2  2021-12  2695.36  20070.24   9550.31  3407.88  39573.81
# 3  2022-01  3003.08  22326.00   9775.93  3609.95  41807.00
# 4  2022-02  3260.83  24178.00   9941.35  3644.23  44117.75
# 5  2022-03  3537.85  31860.65  10237.59  3974.30  44248.91

# %%
CREATE_SQL10 = '''
CREATE TABLE IF NOT EXISTS monthly_mineral(
    id integer auto_increment,
    날짜 TEXT,
    알루미늄 FLOAT,
    니켈 FLOAT,
    동 FLOAT,
    아연 FLOAT,
    주석 FLOAT,
    primary key(id)
    );
    '''

# %%
cur.execute(CREATE_SQL10)
# Out:
# 0

# %%
db.commit()

# %%
sql10 = "INSERT INTO monthly_mineral(날짜,알루미늄,니켈,동,아연,주석) VALUES(%s,%s,%s,%s,%s,%s)"

# %%
for idx in range(len(monthly_mineral)):
    cur.execute(sql10,tuple(monthly_mineral.values[idx]))

# %%
db.commit()
